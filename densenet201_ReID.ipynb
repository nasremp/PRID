# %% [markdown]
# <a href="https://colab.research.google.com/github/nasremp/PRID/blob/main/densenet201_ReID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/KaiyangZhou/deep-person-reid.git
# Out:
# fatal: destination path 'deep-person-reid' already exists and is not an empty directory.

# %%
# %cd deep-person-reid/
# Out:
# /content/deep-person-reid

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda create --name torchreid python=3.9
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/torchreid
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     ca-certificates-2022.6.15  |       ha878542_0         149 KB  conda-forge
#     ld_impl_linux-64-2.36.1    |       hea4e1c9_2         667 KB  conda-forge
#     libffi-3.4.2               |       h7f98852_5          57 KB  conda-forge
#     libgcc-ng-12.1.0           |      h8d9b700_16         940 KB  conda-forge
#     libgomp-12.1.0             |      h8d9b700_16         459 KB  conda-forge
# ...

# %%
! conda activate torchreid
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.7 MB 26.9 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 52.6 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 88.6 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 62.8 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 434 kB/s
# ...
#      |████████████████████████████████| 60.9 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 61.2 MB/s
# ...
#      |████████████████████████████████| 5.9 MB 52.1 MB/s
# ...
#      |████████████████████████████████| 829 kB 58.6 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 61 kB 467 kB/s
# ...
#      |████████████████████████████████| 190 kB 76.0 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 3.4 MB 36.8 MB/s
# ...

# %%
# !conda install pytorch torchvision cudatoolkit=9.0 -c pytorch
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - cudatoolkit=9.0
#
# Current channels:
#
#   - https://conda.anaconda.org/pytorch/linux-64
#   - https://conda.anaconda.org/pytorch/noarch
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
import torchreid
import torch 
print(torch.__version__)
# Out:
# 1.12.1+cu113
# /content/deep-person-reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '

# %% [markdown]
# ## Available PRID models

# %%
torchreid.models.show_avai_models()
# Out:
# ['resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152', 'resnext50_32x4d', 'resnext101_32x8d', 'resnet50_fc512', 'se_resnet50', 'se_resnet50_fc512', 'se_resnet101', 'se_resnext50_32x4d', 'se_resnext101_32x4d', 'densenet121', 'densenet169', 'densenet201', 'densenet161', 'densenet121_fc512', 'inceptionresnetv2', 'inceptionv4', 'xception', 'resnet50_ibn_a', 'resnet50_ibn_b', 'nasnsetmobile', 'mobilenetv2_x1_0', 'mobilenetv2_x1_4', 'shufflenet', 'squeezenet1_0', 'squeezenet1_0_fc512', 'squeezenet1_1', 'shufflenet_v2_x0_5', 'shufflenet_v2_x1_0', 'shufflenet_v2_x1_5', 'shufflenet_v2_x2_0', 'mudeep', 'resnet50mid', 'hacnn', 'pcb_p6', 'pcb_p4', 'mlfn', 'osnet_x1_0', 'osnet_x0_75', 'osnet_x0_5', 'osnet_x0_25', 'osnet_ibn_x1_0', 'osnet_ain_x1_0', 'osnet_ain_x0_75', 'osnet_ain_x0_5', 'osnet_ain_x0_25']

# %% [markdown]
# **Load data manager**
#
# ---

# %%
datamanager = torchreid.data.ImageDataManager(
    root="reid-data",
    sources="market1501",
    targets="market1501",
    height=256,
    width=128,
    batch_size_train=32,
    batch_size_test=100,
    transforms=["random_flip", "random_crop"]
)
# Out:
# Building train transforms ...
# + resize to 256x128
# + random flip
# + random crop (enlarge to 288x144 and crop 256x128)
# + to torch tensor of range [0, 1]
# + normalization (mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# Building test transforms ...
# + resize to 256x128
# + to torch tensor of range [0, 1]
# + normalization (mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# => Loading train (source) dataset
# Creating directory "/content/deep-person-reid/reid-data/market1501"
# ...
# * url="http://188.138.127.15:81/Datasets/Market-1501-v15.09.15.zip"
# * destination="/content/deep-person-reid/reid-data/market1501/Market-1501-v15.09.15.zip"
# ...100%, 145 MB, 4901 KB/s, 30 seconds passed
# Extracting "/content/deep-person-reid/reid-data/market1501/Market-1501-v15.09.15.zip"
# Market1501 dataset is ready
# => Loaded Market1501
#   ----------------------------------------
#   subset   | # ids | # images | # cameras
#   ----------------------------------------
# ...

# %% [markdown]
# **Build model, optimizer and lr_scheduler**

# %%
model = torchreid.models.build_model(
    name="densenet201",
    num_classes=datamanager.num_train_pids,
    loss="softmax",
    pretrained=True
)

model = model.cuda()

optimizer = torchreid.optim.build_optimizer(
    model,
    optim="adam",
    lr=0.0003
)

scheduler = torchreid.optim.build_lr_scheduler(
    optimizer,
    lr_scheduler="single_step",
    stepsize=20
)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet201-c1103571.pth" to /root/.cache/torch/hub/checkpoints/densenet201-c1103571.pth
#   0%|          | 0.00/77.4M [00:00<?, ?B/s]

# %%
engine = torchreid.engine.ImageSoftmaxEngine(
    datamanager,
    model,
    optimizer=optimizer,
    scheduler=scheduler,
    label_smooth=True
)

# %%
engine.run(
    save_dir="log/densenet201",
    max_epoch=60,
    eval_freq=10,
    print_freq=10,
    test_only=False
)
# Out:
# => Start training
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch: [1/60][10/404]	time 0.378 (1.333)	data 0.001 (0.272)	eta 8:58:22	loss 6.6477 (6.6827)	acc 0.0000 (0.3125)	lr 0.000300
# epoch: [1/60][20/404]	time 0.375 (0.856)	data 0.000 (0.137)	eta 5:45:41	loss 6.7610 (6.7499)	acc 0.0000 (0.4688)	lr 0.000300
# epoch: [1/60][30/404]	time 0.378 (0.697)	data 0.000 (0.091)	eta 4:41:15	loss 6.7687 (6.7703)	acc 3.1250 (0.7292)	lr 0.000300
# epoch: [1/60][40/404]	time 0.383 (0.618)	data 0.000 (0.069)	eta 4:09:14	loss 6.5373 (6.7641)	acc 6.2500 (0.7812)	lr 0.000300
# ...
